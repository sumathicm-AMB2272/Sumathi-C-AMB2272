# %% [markdown]
# **Sumathi C- AMB2272**

# %% [markdown]
# ***String***

# %%
fruit="banana"
print(fruit)
print(fruit[2])
# Out:
# banana
# n

# %%
n=3
w=fruit[n-1]
print(w)
# Out:
# n

# %%
n=4
w=fruit[n-1]
print(w)
# Out:
# a

# %%
print(fruit[8])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-2297306023.py in <cell line: 0>()
# ----> 1 print(fruit[8])
#
# IndexError: string index out of range

# %%
print(fruit[2.5])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3703179795.py in <cell line: 0>()
# ----> 1 print(fruit[2.5])
#
# TypeError: string indices must be integers, not 'float'

# %%
a=3
print(fruit[a])
# Out:
# a

# %%
print(fruit['a'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1299995216.py in <cell line: 0>()
# ----> 1 print(fruit['a'])
#
# TypeError: string indices must be integers, not 'str'

# %%
print(len(fruit))
# Out:
# 6

# %%
s="Hello World"
print(s[:4])
# Out:
# Hell

# %%
print(s[6:7])
# Out:
# W

# %%
print(s[6:20])
# Out:
# World

# %%
print(s[:2])
# Out:
# He

# %%
print(s[8:])
# Out:
# rld

# %%
print(s[ : ])
# Out:
# Hello World

# %%
print(s[-8:-1])
# Out:
# lo Worl

# %%
print(s[-9:])
# Out:
# llo World

# %%
print(s[ :-5])
s1=s[ :-5]
print(len(s1))
# Out:
# Hello
# 6

# %%
print(s[-9:-5])
s2=s[-9:-5]
print(len(s2))
# Out:
# llo
# 4

# %%
print(s[-4:-5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1185645761.py in <cell line: 0>()
# ----> 1 print(s[-4:-5])
#
# NameError: name 's' is not defined

# %% [markdown]
# ***String concatination***
# **Joining two strings through "+"**

# %%
str1="Hello"
str2="World"
print(str1+str2)
print(str1+" "+str2)
# Out:
# HelloWorld
# Hello World

# %%
b=str1+"there"
print(b)
# Out:
# Hellothere

# %% [markdown]
# **"+" cannot be used with integer.**

# %%
print(str1+3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3308524272.py in <cell line: 0>()
# ----> 1 print(str1+3)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print(str1+"3")
# Out:
# Hello3

# %%
print(str1*3)
# Out:
# HelloHelloHello

# %%
print(str1+"-"+"there")
# Out:
# Hello-there

# %%
s='Hello''welcome'
print(s)
# Out:
# Hellowelcome

# %%
s=("Hello"
... "welcome")
print(s)
# Out:
# Hellowelcome

# %%
s="Hello"
... "welcome"
print(s)
# Out:
# Hello

# %%
s="Hello"\
  "welcome"
print(s)
# Out:
# Hellowelcome

# %%
s="Hello"
  "world"
print(s)
# Out:
#   File "/tmp/ipython-input-3405585828.py", line 2
#     "world"
#     ^
# IndentationError: unexpected indent

# %%
a="Helloworld"
print(a.count("l"))
# Out:
# 3

# %%
print(a.count("w"))
# Out:
# 1

# %%
print(a.count("o"))
# Out:
# 2

# %%
for i in a:
  if i=="l":
    print(i)
# Out:
# l
# l
# l

# %%
s=0
for i in a:
  if i=="l":
    s=s+1
    print(s)
# Out:
# 1
# 2
# 3

# %%
s=0
for i in a:
  if i=="o":
    s=s+1
    print(s)
# Out:
# 1
# 2

# %%
s=0
for i in a:
  if i=="b":
    s=s+1
    print(s)

# %%
s=0
for i in a:
  if i=="l":
    s=s+1
  print(s)
# Out:
# 0
# 0
# 1
# 2
# 2
# 2
# 2
# 2
# 3
# 3

# %%
s=0
for i in a:
  if i=="l":
    s=s+1
print(s)
# Out:
# 3

# %%
s=0
for i in a:
 if i=="l":
    s=s+1
   print(s)
# Out:
#   File "<tokenize>", line 5
#     print(s)
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
fruit="banana"
print('n' in fruit)
print("m" in fruit)
print('nan' in fruit)
print('naan' in fruit)
# Out:
# True
# False
# True
# False

# %%
if "a" in fruit:
  print("Found it")
# Out:
# Found it

# %%
fruit="bananana"
print(fruit.count("an"))
# Out:
# 3

# %%
fruit="banana"
print(fruit.count("an"))
# Out:
# 2

# %% [markdown]
# **Find-- used to find out the index**

# %%
print(fruit.find("b"))
# Out:
# 0

# %%
print(fruit.find("a"))
# Out:
# 1

# %%
print(fruit.find("n"))
# Out:
# 2

# %%
print(fruit.find("an"))
# Out:
# 1

# %%
print(fruit.find("naa"))
# Out:
# -1

# %% [markdown]
# **lower- to get in lower case**
# **upper - to get in upper case**

# %%
print(fruit.lower())
# Out:
# banana

# %%
print(fruit.upper())
# Out:
# BANANA

# %% [markdown]
# **To get first letter capital-capitalize.**

# %%
s="hello world"
print(s.capitalize())
# Out:
# Hello world

# %%
greet="Hello Morning. Hello Morning"
print(greet.capitalize())
# Out:
# Hello morning. hello morning

# %% [markdown]
# ***Replace***

# %%
greet="Hello morning"
s1=greet.replace("Hello","Good")
print(s1)
print(greet)
# Out:
# Good morning
# Hello morning

# %% [markdown]
# **strip**

# %%
greet="    Hello Morning    "
s1=greet.strip()
print(greet)
print("After striping")
print(s1)
# Out:
#     Hello Morning
# After striping
# Hello Morning

# %% [markdown]
# **lstrip-removes the space in the begining of the sentence.**
# **rstrip-removes the space at end.**

# %%
ls=greet.lstrip()
print(ls+"After striping")
# Out:
# Hello Morning    After striping

# %%
ls=greet.rstrip()
print("After striping"+ls+"Hello")
# Out:
# After striping    Hello MorningHello

# %% [markdown]
# **Split method**

# %%
greet="  Hello Morning"
print(greet.split())
# Out:
# ['Hello', 'Morning']

# %%
a="welcome to GKVK University"
print(a.split())
# Out:
# ['welcome', 'to', 'GKVK', 'University']

# %%
print(a.split(' '))
# Out:
# ['welcome', 'to', 'GKVK', 'University']

# %%
print(a.split(''))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3476600618.py in <cell line: 0>()
# ----> 1 print(a.split(''))
#
# ValueError: empty separator

# %%
print(a.split(','))
# Out:
# ['welcome to GKVK University']

# %%
print(a.split('r'))
# Out:
# ['welcome to GKVK Unive', 'sity']

# %%
print(a.split('e'))
# Out:
# ['w', 'lcom', ' to GKVK Univ', 'rsity']

# %%
print(a.split('E'))
# Out:
# ['welcome to GKVK University']

# %%
str1="Hello"
str2=":".join(str1)
print(str1)
print(str2)
# Out:
# Hello
# H:e:l:l:o

# %%
str1="python"
slen=len(str1)
rev=str1[slen::-1]
print(rev)
# Out:
# nohtyp

# %%
rev=''.join(reversed(str1))
print(rev)
print(str1)
# Out:
# nohtyp
# python

# %%
a='Today is 19-Jan-2026 MONDAY'
bc=0
vc=0
cc=0
for i in a:
  if i==" ":
    bc=bc+1
  elif i=='a' or i=='e' or i=='i' or i=='o' or i=='u':
    vc=vc+1
  else:
    cc=cc+1
print(bc)
print(vc)
print(cc)
# Out:
# 3
# 4
# 20

# %%
a='Today is 20-Jan-2026 TUESDAY'
b=v=c=d=o=0
for i in a:
  if i.isspace():
    b=b+1
  elif i in "aeiouUEA":
    v=v+1
  elif i.isalpha():
    c=c+1
  elif i.isdigit():
    d=d+1
  else:
    o=o+1
print("space",b)
print("Vowels",v)
print("Consonants",c)
print("Digits",d)
print("Others",o)
# Out:
# space 3
# Vowels 7
# Consonants 10
# Digits 6
# Others 2

# %% [markdown]
#  String Manipulation in Python

# %% [markdown]
# Creating Strings
# ""Strings represent textual data such as crop names,soil types, or farmer details.""

# %%
crop="Rice"
soil_type="Black Soil"
print(crop)
print(soil_type)
# Out:
# Rice
# Black Soil

# %% [markdown]
# Length of a String
# The len() function returns the number of characters in a string.

# %%
crop_name="Groundnut"
print(len(crop_name))
print(crop_name[0])
print(crop_name[-1])
print(crop_name[:5])
print(crop_name[5:])
# Out:
# 9
# G
# t
# Groun
# dnut

# %%
print("rice".upper())
print('WHEAT'.lower())
print("green gram".title())
print("cotton crop".capitalize())
# Out:
# RICE
# wheat
# Green Gram
# Cotton crop

# %%
raw_crop="Rice"
print(raw_crop.strip())
print("***Wheat".lstrip("*"))
print("Maize###".rstrip("#"))
# Out:
# Rice
# Wheat
# Maize

# %%
text="Organic Rice and Rice cultivation"
print(text.find("Rice"))
print(text.count("Rice"))
print("Rice" in text)
# Out:
# 8
# 2
# True

# %% [markdown]
# Validation and checking methods.
# used for validating form inputs.

# %%
print("Rice".isalpha())
print("2026".isdigit())
print("Plot12".isalnum())
print("  ".isspace())
# Out:
# True
# True
# True
# True

# %% [markdown]
# Replace string content
# used to update or correct crop records.

# %%
crop_info="Rice Crop"
updated_crop_info=crop_info.replace("Rice","Wheat")
print(updated_crop_info)
# Out:
# Wheat Crop

# %% [markdown]
# Spliting and joining strings
# Common in CSV-style agriculture datasets.

# %%
record="Rice,1200,Black Soil"
fields=record.split(",")
print(fields)
# Out:
# ['Rice', '1200', 'Black Soil']

# %%
joined_record=",".join(fields)
print(joined_record)
# Out:
# Rice,1200,Black Soil

# %% [markdown]
# String formatting.
# Formatting improves readability of output.

# %%
crop="Rice"
yield_kg=1200
print(f'Crop:{crop},Yield:{yield_kg}kg')
print("Crop:{} Yield:{}".format(crop,yield_kg))
# Out:
# Crop:Rice,Yield:1200kg
# Crop:Rice Yield:1200

# %% [markdown]
# Escape Characters
# Used for formatting text output.

# %%
print("Farmer's crop record")
print("Line1\nLine2")
print(sorted("wheaT"))
# Out:
# Farmer's crop record
# Line1
# Line2
# ['T', 'a', 'e', 'h', 'w']

# %%
crop_code="CRP_RICE_2026"
print(crop_code.startswith("CRP"))
print(crop_code.endswith("2025"))
# Out:
# True
# False

# %% [markdown]
# Extracting ALL strings with a prefix

# %%
codes=[
  "CRP_RICE_2026",
  "CRP_WHEAT_2025",
  "FRT_MANGO_2026",
  "CRP_MAIZE_2024"
]
filtered=[]
for crop_code in codes:
  if crop_code.startswith("CRP_"):
    filtered.append(crop_code)
print(filtered)
# Out:
# ['CRP_RICE_2026', 'CRP_WHEAT_2025', 'CRP_MAIZE_2024']

# %% [markdown]
# Extract and clean in one go

# %%
clean_codes=[]
for code in codes:
  if code.startswith("CRP_"):
    clean_codes.append(code[4:])
print(clean_codes)
# Out:
# ['RICE_2026', 'WHEAT_2025', 'MAIZE_2024']

# %% [markdown]
# Split method

# %%
for crop_code in codes:
  if crop_code.startswith("CRP_"):
    code,crop,year=crop_code.split('_')
    print(crop,year)
# Out:
# RICE 2026
# WHEAT 2025
# MAIZE 2024

# %% [markdown]
# Mini Agriculture Data Cleaning Example
# A consolidated example using multiple string operations.

# %%
raw_record=" Rice,1200,Black Soil**"
clean_record=raw_record.strip()
clean_record1=clean_record.rstrip("*")
crop,yield_kg,soil=clean_record1.split(",")
crop=crop.title()

print(f"Crop:{crop}")
print(f"Yield:{yield_kg}kg")
print(f"Soil Type:{soil}")
# Out:
# Crop:Rice
# Yield:1200kg
# Soil Type:Black Soil
